# %% [markdown]
# # modeling_v13 — 2차 선별: **Balanced + RFECV**
#
# **목적**: M1 다이어트 `Balanced` 셋에 RFECV 2차 선별을 얹어, 최종 OOF로 비교.
# **RFECV(수동)** — prunable 피처를 gain 하위부터 step(5)개씩 제거하며 GroupKFold(C20) OOF 곡선을 그려 **최소 RMSE 크기**를 고른다.
#
# **고정(항상 포함)**: core10(10) + 필수 5센서 champion → floor(5센서≥1) 보장·백본.
# **가변(prunable)**: `Balanced` diet − 고정. 여기서만 RFECV가 부분집합을 고른다.
# **선별 목적함수**: `GroupKFold(C20)` OOF (신규 Lot 정직-CV) — 프로젝트 결정지표.
# **최종 보고**: 고른 셋 + baseline(2차선별 없음)을 `M8_PARAMS`·705로 **KFold + GroupKFold** 둘 다.
#
# > ⚠️ 전제: `v13_select_common.py`, `../modeling_v8/v8_timeline_common.py`,
# > `../문제1(하)/train_data.csv`, `../pm_log.json`, `feature_diet_selected.json`,
# > `data/v13_fdc_pool_wf_oof.csv.gz` 가 제자리에 있어야 함. **CPU 전용(GPU 이득 없음).**
# > 4개 노트북(Cons/Bal × RFECV/GA)은 서로 독립 — **병렬 실행 가능**.

# %%
import warnings; warnings.filterwarnings("ignore")
import json, pandas as pd
import v13_select_common as sc

PRESET = "Balanced"
METHOD = "RFECV"

# %% [markdown]
# ## 1. 로드 & 피처 그룹 (고정/가변)

# %%
df, y, groups, g = sc.load(PRESET)
ok, have = sc.floor_ok(g["fixed"])
print("df:", df.shape)
print(f"fixed(core10+champion)={len(g['fixed'])}  prunable(diet-fixed)={len(g['prunable'])}")
print("fixed floor:", ok, have)
# Out:
# df: (11939, 667)
# fixed(core10+champion)=15  prunable(diet-fixed)=121
# fixed floor: True {'C17': 1, 'C11': 1, 'C31': 1, 'C15': 1, 'C16': 1}

# %% [markdown]
# ## 2. RFECV 선별
#
# **RFECV(수동)** — prunable 피처를 gain 하위부터 step(5)개씩 제거하며 GroupKFold(C20) OOF 곡선을 그려 **최소 RMSE 크기**를 고른다.

# %%
# RFECV 선별 (step=5, min_keep=10, 5-fold). 런타임 ~2–3분.
res = sc.rfe_cv(df, y, groups, g["fixed"], g["prunable"],
                step=5, min_keep=10, n_splits=5, verbose=True)
selected = res["best_subset"]
print(f"\nRFECV 선택: prunable {len(g['prunable'])} -> {len(selected)}  (best GKF={res['best_rmse']:.3f})")
# Out:
#   RFE  prunable=121  GKF_RMSE=69.763
#   RFE  prunable=116  GKF_RMSE=69.961
#   RFE  prunable=111  GKF_RMSE=69.841
#   RFE  prunable=106  GKF_RMSE=69.825
#   RFE  prunable=101  GKF_RMSE=69.939
#   RFE  prunable= 96  GKF_RMSE=69.745
#   RFE  prunable= 91  GKF_RMSE=69.989
#   RFE  prunable= 86  GKF_RMSE=69.954
#   RFE  prunable= 81  GKF_RMSE=69.692
#   RFE  prunable= 76  GKF_RMSE=69.745
#   RFE  prunable= 71  GKF_RMSE=69.862
#   RFE  prunable= 66  GKF_RMSE=69.653
#   RFE  prunable= 61  GKF_RMSE=69.802
#   RFE  prunable= 56  GKF_RMSE=70.003
#   RFE  prunable= 51  GKF_RMSE=70.183
#   RFE  prunable= 46  GKF_RMSE=69.830
#   RFE  prunable= 41  GKF_RMSE=70.035
#   RFE  prunable= 36  GKF_RMSE=69.887
#   RFE  prunable= 31  GKF_RMSE=70.216
#   RFE  prunable= 26  GKF_RMSE=70.463
#   RFE  prunable= 21  GKF_RMSE=70.450
#   RFE  prunable= 16  GKF_RMSE=70.650
#   RFE  prunable= 11  GKF_RMSE=70.814
#   RFE  prunable= 10  GKF_RMSE=71.347
#
# RFECV 선택: prunable 121 -> 66  (best GKF=69.653)

# %% [markdown]
# ## 3. 최종 OOF — 선택셋 vs baseline(2차선별 없음) · M8_PARAMS·705

# %%
baseline = sc.final_report(df, y, groups, g["fixed"], g["prunable"], f"{PRESET}+diet(no-2nd)")
best     = sc.final_report(df, y, groups, g["fixed"], selected,       f"{PRESET}+{METHOD}")
tbl = pd.DataFrame([baseline, best])[["label","n_total","n_selected",
                                      "KFold_OOF","GroupKFold_C20","floor_ok"]]
print(tbl.to_string(index=False))
tbl
# Out:
#                 label  n_total  n_selected  KFold_OOF  GroupKFold_C20  floor_ok
# Balanced+diet(no-2nd)      136         121     51.648          71.254      True
#        Balanced+RFECV       81          66     51.339          71.445      True
#                    label  n_total  n_selected  KFold_OOF  GroupKFold_C20  \
# 0  Balanced+diet(no-2nd)      136         121     51.648          71.254
# 1         Balanced+RFECV       81          66     51.339          71.445
#
#    floor_ok
# 0      True
# 1      True

# %% [markdown]
# ## 4. floor 재확인 & 선택 피처

# %%
okb, haveb = sc.floor_ok(best["features"])
assert okb, "FLOOR VIOLATION"
print("final floor:", okb, haveb)
print(f"selected prunable ({len(selected)}):")
for f in sorted(selected):
    print("  ", f)
# Out:
# final floor: True {'C17': 3, 'C11': 2, 'C31': 2, 'C15': 1, 'C16': 2}
# selected prunable (66):
#    C11_max_step4
#    C12_mean_step1
#    C16_mean_step4
#    C17_min_step1
#    C17_std_step1
#    C18_max_step4
#    C18_max_step6
#    C25_last_step1
#    C25_last_step4
#    C25_last_step6
#    C25_last_step7
#    C25_max_step1
#    C25_max_step6
#    C25_mean_step4
#    C25_min_step4
#    C25_min_step6
#    C25_min_step7
#    C25_std_step1
#    C25_std_step4
#    C25_std_step7
#    C27_last_step4
#    C27_max_step4
#    C27_std_step4
#    C31_max_step4
#    C4_max_step1
#    C52_last_step6
#    C52_max_step7
#    C52_mean_step1
#    C52_min_step4
#    C52_std_step1
#    C52_std_step4
#    C52_std_step7
#    C54_mean_step4
#    C54_std_step4
#    C56_last_step4
#    C56_mean_step4
#    C56_std_step4
#    C57_mean_step4
#    C58_mean_step1
#    C58_mean_step4
#    C58_std_step4
#    C59_max_step7
#    C59_std_step1
#    C59_std_step4
#    C59_std_step7
#    C60_min_step1
#    C60_std_step1
#    C60_std_step4
#    C60_std_step7
#    C61_last_step1
#    C61_last_step6
#    C61_last_step7
#    C61_min_step4
#    C61_min_step6
#    C61_std_step7
#    C62_last_step4
#    C62_max_step4
#    C62_max_step6
#    C62_max_step7
#    C62_mean_step1
#    C62_mean_step4
#    C62_min_step6
#    C62_std_step1
#    C62_std_step7
#    C63_min_step4
#    C63_std_step4

# %% [markdown]
# ## 5. 산출물 저장 (4개 노트북 결과 통합용)

# %%
out = {"preset": PRESET, "method": METHOD,
       "baseline": {k: baseline[k] for k in ["n_total","KFold_OOF","GroupKFold_C20"]},
       "selected_result": {k: best[k] for k in ["n_total","n_selected","KFold_OOF","GroupKFold_C20","floor_ok"]},
       "selected_features": sorted(selected)}
fn = f"select_result_{PRESET}_{METHOD}.json"
json.dump(out, open(fn, "w", encoding="utf-8"), ensure_ascii=False, indent=2)
print("saved:", fn)
# Out:
# saved: select_result_Balanced_RFECV.json

# %% [markdown]
# ---
# ### 4개 노트북 통합 비교 (모두 실행 후)
# 각 노트북이 `select_result_<preset>_<method>.json` 을 남긴다. 4개를 모아 GroupKFold(C20) 기준으로
# 최저 RMSE 조합을 고르면 된다 (동률 시 더 슬림한 `n_total` 우선).
